# %%
import sys
sys.path.append('../src')
import main_all
% matplotlib inline

# %%
main_all.main_all(settings='big', DAC_SPEED=3, DISTRIBUTION='Uniform')
# Out:
# [100, 5, 4, 3]
#        name duration (s)
# 0        DE   4.64+-1.48
# 1        GA    3.4+-1.45
# 2  Proposed   0.15+-0.02
# 3    Random     0.0+-0.0
# [500, 10, 8, 6]
#        name duration (s)
# 0        DE   9.82+-5.41
# 1        GA   10.29+-7.3
# 2  Proposed   1.71+-1.61
# 3    Random    0.0+-0.01
# [1000, 20, 16, 15]
#        name  duration (s)
# 0        DE    28.1+-28.4
# 1        GA  34.95+-35.97
# 2  Proposed     8.1+-9.29
# 3    Random    0.01+-0.01

# %%
main_all.main_all(settings='big', DAC_SPEED=3, DISTRIBUTION='Normal')
# Out:
# [100, 5, 4, 3]
#        name duration (s)
# 0        DE   5.17+-0.02
# 1        GA   3.66+-1.22
# 2  Proposed   0.14+-0.01
# 3    Random     0.0+-0.0
# [500, 10, 8, 6]
#        name duration (s)
# 0        DE   10.1+-5.06
# 1        GA  10.43+-7.13
# 2  Proposed    1.7+-1.61
# 3    Random    0.0+-0.01
# [1000, 20, 16, 15]
#        name  duration (s)
# 0        DE  30.18+-29.16
# 1        GA   34.92+-35.7
# 2  Proposed    8.12+-9.33
# 3    Random    0.01+-0.01

# %%
# main_all.main_all(settings='big', DAC_SPEED=3, RESCALE=False, DISTRIBUTION='Uniform')

# %%
# main_all.main_all(settings='big', DAC_SPEED=2, RESCALE=False, DISTRIBUTION='Normal')

# %%
# main_all.main_all(settings='big', DAC_SPEED=1, RESCALE=False, DISTRIBUTION='Normal')
