# %%
import sys
sys.path.append('../src')
import main_all
% matplotlib inline

# %%
main_all.main_all(settings='small', DAC_SPEED=3, DISTRIBUTION='Uniform')
# Out:
# [5, 2, 2, 2]
#        name duration (s)
# 0        DE   0.63+-0.39
# 1        GA   0.12+-0.03
# 2   Optimal     0.0+-0.0
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 3, 2, 2]
#        name duration (s)
# 0        DE   0.93+-0.56
# 1        GA   0.15+-0.06
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 3, 2, 3]
#        name duration (s)
# 0        DE    1.09+-0.6
# 1        GA   0.17+-0.07
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [9, 3, 2, 2]
#        name duration (s)
# 0        DE   1.48+-0.86
# 1        GA   0.21+-0.11
# 2   Optimal    0.07+-0.1
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [14, 3, 4, 3]
#        name duration (s)
# 0        DE   2.06+-1.39
# 1        GA   0.45+-0.64
# 2   Optimal    0.07+-0.1
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0

# %%
main_all.main_all(settings='small', DAC_SPEED=3, DISTRIBUTION='Normal')
# Out:
# [5, 2, 2, 2]
#        name duration (s)
# 0        DE   0.55+-0.28
# 1        GA   0.12+-0.04
# 2   Optimal     0.0+-0.0
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 3, 2, 2]
#        name duration (s)
# 0        DE   0.91+-0.53
# 1        GA   0.15+-0.06
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 3, 2, 3]
#        name duration (s)
# 0        DE   1.08+-0.62
# 1        GA   0.16+-0.06
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [9, 3, 2, 2]
#        name duration (s)
# 0        DE   1.45+-0.88
# 1        GA    0.2+-0.12
# 2   Optimal    0.07+-0.1
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [14, 3, 4, 3]
#        name duration (s)
# 0        DE   2.03+-1.41
# 1        GA   0.47+-0.66
# 2   Optimal    0.07+-0.1
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0

# %%
# main_all.main_all(settings='small', DAC_SPEED=3, RESCALE=False, DISTRIBUTION='Uniform')

# %%
# main_all.main_all(settings='small', DAC_SPEED=2, RESCALE=False, DISTRIBUTION='Normal')

# %%
# main_all.main_all(settings='small', DAC_SPEED=1, RESCALE=False, DISTRIBUTION='Normal')
