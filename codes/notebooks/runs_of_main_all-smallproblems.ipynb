# %%
import sys
sys.path.append('../src')
import main_all
% matplotlib inline

# %%
main_all.main_all(settings='small', DAC_SPEED=3, RESCALE=False, DISTRIBUTION='Normal')
# Out:
# [5, 2, 2, 1]
#        name duration (s)
# 0        DE   0.56+-0.31
# 1        GA   0.12+-0.06
# 2   Optimal     0.0+-0.0
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 2, 2, 1]
#        name duration (s)
# 0        DE   1.19+-0.87
# 1        GA   0.17+-0.11
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 3, 2, 1]
#        name duration (s)
# 0        DE    1.18+-0.8
# 1        GA    0.16+-0.1
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [9, 2, 4, 1]
#        name duration (s)
# 0        DE   1.61+-1.14
# 1        GA   0.29+-0.29
# 2   Optimal   0.11+-0.17
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [12, 2, 4, 2]
#        name duration (s)
# 0        DE   2.03+-1.32
# 1        GA    0.5+-0.62
# 2   Optimal    4.95+-9.7
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0

# %%
# main_all.main_all(settings='small', DAC_SPEED=3, RESCALE=False, DISTRIBUTION='Uniform')

# %%
# main_all.main_all(settings='small', DAC_SPEED=2, RESCALE=False, DISTRIBUTION='Normal')

# %%
# main_all.main_all(settings='small', DAC_SPEED=1, RESCALE=False, DISTRIBUTION='Normal')
