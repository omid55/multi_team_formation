# %%
import sys
sys.path.append('../src')
import main_all
% matplotlib inline

# %%
main_all.main_all()
# Out:
# [5, 2, 2, 1]
#        name duration (s)
# 0        DE   0.45+-0.19
# 1        GA   0.09+-0.02
# 2   Optimal     0.0+-0.0
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 2, 2, 1]
#        name duration (s)
# 0        DE   1.24+-1.11
# 1        GA   0.13+-0.06
# 2   Optimal   0.02+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 3, 2, 1]
#        name duration (s)
# 0        DE   1.34+-0.98
# 1        GA   0.77+-1.03
# 2   Optimal   0.02+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [9, 2, 4, 1]
#        name duration (s)
# 0        DE    1.28+-0.9
# 1        GA   0.62+-0.93
# 2   Optimal   0.12+-0.18
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
