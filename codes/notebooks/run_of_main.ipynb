# %%
import sys
sys.path.append('../src')
import main
% matplotlib inline

# %%
main.main()
# Out:
# Solutions:
#
# Random:				 0.760450004129
# Valid:  True
# (in  0.01 s).
#
# Divide&Conquer:	 1.26623433445
# Valid:  True
# (in  7.53 s).
#
# DE:				 0.891256901651
# Valid:  True
# (in  63.16 s).
#
# GA:				 0.964655592054
# Valid:  True
# (in  86.4 s).
