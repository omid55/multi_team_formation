# %%
import sys
sys.path.append('../src')
import main
% matplotlib inline

# %%
main.main()
# Out:
# Solutions:
#
# Random:				 0.412615637388
# Valid:  True
# (in  0.0 s).
#
# Divide&Conquer:	 0.58685450012
# Valid:  True
# (in  0.0 s).
#
# DE:				 0.58685450012
# Valid:  True
# (in  2.01 s).
#
# GA:				 0.58685450012
# Valid:  True
# (in  1.04 s).
#
# Optimal:		 0.58685450012
# (in  0.02 s).
