# %%
import sys
sys.path.append('../src')
import main
% matplotlib inline

# %%
main.main()
# Out:
# Solutions:
#
# Divide&Conquer:	 1.32436894577
# Valid:  True
# (in  5.9 s).
#
# DE:				 0.903652038483
# Valid:  True
# (in  51.14 s).
#
# Random:				 0.730497098165
# Valid:  True
# (in  0.0 s).
#
# GA:				 1.01840382291
# Valid:  True
# (in  74.44 s).
