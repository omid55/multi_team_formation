# %%
import sys
sys.path.append('../src')
import main
% matplotlib inline

# %%
main.main()
# Out:
# Solutions:
#
# Divide&Conquer:	 1.23935170287
# Valid:  True
# (in  5.89 s).
#
# DE:				 0.902563339312
# Valid:  True
# (in  45.36 s).
#
# Random:				 0.6322473183
# Valid:  True
# (in  0.0 s).
#
# GA:				 0.99849191217
# Valid:  True
# (in  44.75 s).
