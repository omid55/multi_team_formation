# %%
import sys
sys.path.append('../src')
import main_all
% matplotlib inline

# %%
main_all.main_all()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-03b52c74bf8b> in <module>()
# ----> 1 main_all.main_all()
#
# ~/Dropbox/Projects/MultiTeamFormation/codes/src/main_all.py in main_all()
#      24
#      25             byGA = methods.GeneticAlgorithm(problem)
# ---> 26             objectives.append(['GA', problem.objective_function(byGA.solve())])
#      27
#      28             byoptimal = methods.ByOptimal(problem)
#
# ~/Dropbox/Projects/MultiTeamFormation/codes/src/methods.py in solve(self, settings)
#     265
#     266             # adding new generation and theirs fitness to rest of population and fitnesses
# --> 267             new_fitnesses = compute_fitness_for_all(self.problem, new_generation)
#     268             population.extend(new_generation)
#     269             fitnesses = np.concatenate((fitnesses, new_fitnesses))
#
# ...
