# %%
import sys
sys.path.append('../src')
import main
% matplotlib inline

# %%
main.main()
# Out:
# Solutions:
#
# Divide&Conquer:	 1.6067009253
# Valid:  True
# (in  6.09 s).
#
# DE:				 0.937487021918
# Valid:  True
# (in  28.54 s).
#
# Random:				 0.485029659448
# (in  0.0 s).
#
# Valid:  True
# GA:				 1.09470334174
# Valid:  True
# (in  51.47 s).
