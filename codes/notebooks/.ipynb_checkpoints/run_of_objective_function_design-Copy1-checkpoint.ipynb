# %%
# Omid55
import sys
sys.path.append('../src')
import objective_function_design
% matplotlib inline

# %%
objective_function_design.main()
# Out:
# <bound method Problem.score1 of <teams_of_teams_problem.Problem object at 0x7eff783fc0f0>>
# min: 0.911764480385 , max: 0.94158295868 , mean: 0.929112183363 , std: 0.00391881198403
# (in  24.41 s).
# Linear transformation: (x- 0.911764480385 )* 33.5362519205
# <bound method Problem.score2 of <teams_of_teams_problem.Problem object at 0x7eff783fc0f0>>
# min: 0.509381137144 , max: 0.551246591894 , mean: 0.530263576461 , std: 0.00507154737639
# (in  18.7 s).
# Linear transformation: (x- 0.509381137144 )* 23.8860417488
# <bound method Problem.score3 of <teams_of_teams_problem.Problem object at 0x7eff783fc0f0>>
# min: 0.259470842156 , max: 0.348387614121 , mean: 0.29521291845 , std: 0.0127751519497
# (in  43.99 s).
# Linear transformation: (x- 0.259470842156 )* 11.2464721548
# <bound method Problem.objective_function of <teams_of_teams_problem.Problem object at 0x7eff783fc0f0>>
# min: 0.56923503031 , max: 0.605475115826 , mean: 0.584862892758 , std: 0.00479973794895
# (in  88.54 s).
# ...
