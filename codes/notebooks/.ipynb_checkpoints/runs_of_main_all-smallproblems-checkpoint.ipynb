# %%
import sys
sys.path.append('../src')
import main_all
% matplotlib inline

# %%
main_all.main_all(settings='small', DAC_SPEED=3, RESCALE=False, DISTRIBUTION='Normal')
# Out:
# [5, 2, 2, 1]
#        name duration (s)
# 0        DE   0.46+-0.27
# 1        GA   0.12+-0.03
# 2   Optimal     0.0+-0.0
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 2, 2, 1]
#        name duration (s)
# 0        DE   1.18+-0.91
# 1        GA   0.16+-0.09
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 3, 2, 1]
#        name duration (s)
# 0        DE   1.09+-0.79
# 1        GA   0.18+-0.09
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [9, 2, 4, 1]
#        name duration (s)
# 0        DE   1.64+-1.18
# 1        GA   0.26+-0.19
# 2   Optimal   0.11+-0.17
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [12, 2, 4, 2]
#        name duration (s)
# 0        DE   2.05+-1.34
# 1        GA   0.46+-0.55
# 2   Optimal   4.97+-9.74
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0

# %%
main_all.main_all(settings='small', DAC_SPEED=3, RESCALE=False, DISTRIBUTION='Uniform')
# Out:
# [5, 2, 2, 1]
#        name duration (s)
# 0        DE   0.45+-0.28
# 1        GA   0.12+-0.05
# 2   Optimal     0.0+-0.0
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 2, 2, 1]
#        name duration (s)
# 0        DE    1.17+-0.9
# 1        GA   0.18+-0.12
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [7, 3, 2, 1]
#        name duration (s)
# 0        DE   1.14+-0.77
# 1        GA    0.19+-0.1
# 2   Optimal   0.01+-0.01
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0
# [9, 2, 4, 1]
#        name duration (s)
# 0        DE   1.65+-1.14
# 1        GA   0.25+-0.15
# 2   Optimal   0.12+-0.18
# 3  Proposed     0.0+-0.0
# 4    Random     0.0+-0.0

# %%
main_all.main_all(settings='small', DAC_SPEED=2, RESCALE=False, DISTRIBUTION='Normal')
# Out:
# [5, 2, 2, 1]
#        name duration (s)
# 0        DE   0.51+-0.22
# 1        GA   0.13+-0.05
# 2   Optimal     0.0+-0.0
# 3  Proposed    0.04+-0.0
# 4    Random     0.0+-0.0
# [7, 2, 2, 1]
#        name duration (s)
# 0        DE   1.27+-0.91
# 1        GA   0.19+-0.14
# 2   Optimal   0.01+-0.01
# 3  Proposed   0.06+-0.02
# 4    Random     0.0+-0.0
# [7, 3, 2, 1]
#        name duration (s)
# 0        DE   1.17+-0.82
# 1        GA   0.21+-0.12
# 2   Optimal   0.01+-0.01
# 3  Proposed   0.05+-0.02
# 4    Random     0.0+-0.0
# [9, 2, 4, 1]
#        name duration (s)
# 0        DE   1.66+-1.16
# 1        GA   0.28+-0.25
# 2   Optimal   0.11+-0.18
# 3  Proposed   0.07+-0.03
# 4    Random     0.0+-0.0

# %%
main_all.main_all(settings='small', DAC_SPEED=1, RESCALE=False, DISTRIBUTION='Normal')
# Out:
# [5, 2, 2, 1]
#        name duration (s)
# 0        DE   0.46+-0.24
# 1        GA   0.13+-0.04
# 2   Optimal     0.0+-0.0
# 3  Proposed   0.09+-0.01
# 4    Random     0.0+-0.0
# [7, 2, 2, 1]
#        name duration (s)
# 0        DE    1.19+-0.9
# 1        GA   0.19+-0.13
# 2   Optimal   0.01+-0.01
# 3  Proposed   0.13+-0.04
# 4    Random     0.0+-0.0
# [7, 3, 2, 1]
#        name duration (s)
# 0        DE   1.09+-0.79
# 1        GA    0.2+-0.11
# 2   Optimal   0.01+-0.01
# 3  Proposed   0.11+-0.04
# 4    Random     0.0+-0.0
# [9, 2, 4, 1]
#        name duration (s)
# 0        DE   1.62+-1.18
# 1        GA   0.26+-0.18
# 2   Optimal   0.12+-0.18
# 3  Proposed   0.15+-0.06
# 4    Random     0.0+-0.0
