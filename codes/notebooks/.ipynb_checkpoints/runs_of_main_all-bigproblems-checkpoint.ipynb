# %%
import sys
sys.path.append('../src')
import main_all
% matplotlib inline

# %%
main_all.main_all(settings='big', DAC_SPEED=3, RESCALE=False, DISTRIBUTION='Normal')
# Out:
# [100, 5, 4, 1]
#        name duration (s)
# 0        DE   4.31+-0.03
# 1        GA   3.39+-0.67
# 2  Proposed   0.06+-0.02
# 3    Random     0.0+-0.0
# [500, 10, 8, 4]
#        name duration (s)
# 0        DE   8.54+-4.35
# 1        GA   9.57+-6.36
# 2  Proposed    0.7+-0.66
# 3    Random     0.0+-0.0
# [1000, 20, 16, 8]
#        name  duration (s)
# 0        DE  23.38+-21.63
# 1        GA  28.32+-27.47
# 2  Proposed    3.08+-3.46
# 3    Random    0.01+-0.01

# %%
main_all.main_all(settings='big', DAC_SPEED=3, RESCALE=False, DISTRIBUTION='Uniform')
# Out:
# [100, 5, 4, 1]
#        name duration (s)
# 0        DE   4.37+-0.02
# 1        GA   3.14+-0.94
# 2  Proposed   0.05+-0.01
# 3    Random     0.0+-0.0
# [500, 10, 8, 4]
#        name duration (s)
# 0        DE   8.58+-4.32
# 1        GA   9.22+-6.39
# 2  Proposed    0.7+-0.66
# 3    Random     0.0+-0.0
# [1000, 20, 16, 8]
#        name  duration (s)
# 0        DE  23.06+-21.13
# 1        GA   27.79+-27.2
# 2  Proposed     3.0+-3.36
# 3    Random    0.01+-0.01

# %%
main_all.main_all(settings='big', DAC_SPEED=2)
# Out:
# [100, 5, 4, 1]
#        name duration (s)
# 0        DE   4.26+-0.02
# 1        GA   3.45+-0.66
# 2  Proposed   5.03+-0.13
# 3    Random     0.0+-0.0
# [500, 10, 8, 4]
#        name  duration (s)
# 0        DE    8.34+-4.18
# 1        GA    9.38+-6.11
# 2  Proposed  45.05+-41.06
# 3    Random      0.0+-0.0
# [1000, 20, 16, 8]
#        name    duration (s)
# 0        DE    22.72+-20.96
# 1        GA    27.75+-26.88
# 2  Proposed  239.33+-281.43
# 3    Random      0.01+-0.01

# %%
main_all.main_all(settings='big', DAC_SPEED=1)
# Out:
# [100, 5, 4, 1]
#        name duration (s)
# 0        DE   4.23+-0.01
# 1        GA   2.95+-0.63
# 2  Proposed   8.24+-0.07
# 3    Random     0.0+-0.0
# [500, 10, 8, 4]
#        name    duration (s)
# 0        DE       7.92+-4.1
# 1        GA      8.73+-6.15
# 2  Proposed  148.26+-143.68
# 3    Random        0.0+-0.0
# [1000, 20, 16, 8]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-40ce00edbfe9> in <module>()
# ----> 1 main_all.main_all(settings='big', DAC_SPEED=1)
#
# ~/Dropbox/Projects/MultiTeamFormation/codes/src/main_all.py in main_all(settings, DAC_SPEED)
#      46                 settings = {'population_size': 50, 'crossover_prob': 0.8, 'mutation_prob': 0.3,\
#      47                         'max_iteration': 100, 'gene_permutation_portion': 0.2, 'eps': 0.0001,\
# ---> 48                         'with_figure': False})))
#      49             times.append(['GA', round(time.time() - start_time, 2)])
#      50
#
# ~/Dropbox/Projects/MultiTeamFormation/codes/src/methods.py in solve(self, settings)
#     349
#     350             # mutation
# --> 351             mutated_children = self.mutate(children, mutation_prob, gene_permutation_portion)
#     352
#     353             # the new generation
#
# ~/Dropbox/Projects/MultiTeamFormation/codes/src/methods.py in mutate(self, population, permutation_prob, gene_permutation_portion)
#     478                 chromosome = population[i].copy()
#     479                 for i in range(gene_permutation_times):
# --> 480                     selected = np.random.choice(range(L), 2, replace=False)           # choose 2 genes by random
#     481                     i1 = selected[0]
#     482                     i2 = selected[1]
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ~/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims)
#    2406
#    2407
# -> 2408 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue):
#    2409     """
#    2410     Return the product of array elements over a given axis.
#
# KeyboardInterrupt:
