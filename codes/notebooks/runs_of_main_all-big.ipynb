# %%
import sys
sys.path.append('../src')
import main_all
% matplotlib inline

# %%
main_all.main_all(settings='big')
# Out:
# [100, 5, 4, 1]
#        name duration (s)
# 0        DE   4.21+-0.04
# 1        GA    2.28+-1.0
# 2  Proposed   0.06+-0.02
# 3    Random     0.0+-0.0
# [500, 10, 8, 4]
#        name duration (s)
# 0        DE   7.24+-3.11
# 1        GA   6.93+-5.22
# 2  Proposed   0.74+-0.69
# 3    Random     0.0+-0.0
# [1000, 20, 16, 8]
#        name  duration (s)
# 0        DE  16.03+-12.89
# 1        GA  19.54+-18.67
# 2  Proposed    3.11+-3.47
# 3    Random      0.0+-0.0
